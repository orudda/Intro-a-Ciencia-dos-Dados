# %%
from controller import *

# %%
df = pd.read_csv('owid-covid-data.csv')
for col in df.columns: 
    print(col)
# Out:
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# new_tests
# total_tests
# total_tests_per_thousand
# new_tests_per_thousand
# new_tests_smoothed
# new_tests_smoothed_per_thousand
# tests_per_case
# positive_rate
# tests_units
# stringency_index
# population
# population_density
# median_age
# aged_65_older
# aged_70_older
# gdp_per_capita
# extreme_poverty
# cardiovasc_death_rate
# diabetes_prevalence
# female_smokers
# male_smokers
# handwashing_facilities
# hospital_beds_per_thousand
# life_expectancy
# human_development_index

# %%
#Abrindo e filtrando o csv para pegar paises da America do Sul
n_days = True #Caso queira o df com coluna de dias
# columns = ['continent', 'location', 'date', 'total_cases', 'new_cases']
columns = ['continent', 'location', 'date', 'new_cases']
df = load_df(columns)
df_ARG, df_BOL, df_BRA, df_CHI, df_COL, df_ECU, df_FIS, df_GUY, df_PAR, df_PER, df_SUR, df_URU, df_VEN = comum_preprocess(df, n_days)
# Out:
# /home/rudda/Desktop/2020-1/icd/TRABALHO ICD/controller.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days'] = dates

# %%
print(df_ARG)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_BOL)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_BRA)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_CHI)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_COL)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_ECU)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_FIS)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_GUY)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_PAR)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_PER)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_SUR)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_URU)
print("\n\n\n-----------------------------------------------------------------------------------")
print(df_VEN)
# Out:
#           continent   location        date  new_cases  days
# 1570  South America  Argentina  2020-03-04        1.0     1
# 1571  South America  Argentina  2020-03-05        NaN     2
# 1572  South America  Argentina  2020-03-06        1.0     3
# 1573  South America  Argentina  2020-03-07        6.0     4
# 1574  South America  Argentina  2020-03-08        1.0     5
# ...             ...        ...         ...        ...   ...
# 1777  South America  Argentina  2020-09-27    11249.0   208
# 1778  South America  Argentina  2020-09-28     8841.0   209
# 1779  South America  Argentina  2020-09-29    11807.0   210
# 1780  South America  Argentina  2020-09-30    13477.0   211
# 1781  South America  Argentina  2020-10-01    14392.0   212
#
# [212 rows x 5 columns]
#
#
#
# -----------------------------------------------------------------------------------
#           continent location        date  new_cases  days
# 5888  South America  Bolivia  2020-03-12        2.0     1
# ...

# %%
# plt.show
df_ARG.plot(x='days', y='new_cases', kind='line')
plt.title('argentina')
df_BOL.plot(x='days', y='new_cases', kind='line')
plt.title('bolivia')
df_BRA.plot(x='days', y='new_cases', kind='line')
plt.title('brasil')
df_CHI.plot(x='days', y='new_cases', kind='line')
plt.title('chile')
df_COL.plot(x='days', y='new_cases', kind='line')
plt.title('colombia')
df_ECU.plot(x='days', y='new_cases', kind='line')
plt.title('ecuador')
df_FIS.plot(x='days', y='new_cases', kind='line')
plt.title('maldivas')
df_GUY.plot(x='days', y='new_cases', kind='line')
plt.title('guiana')
df_PAR.plot(x='days', y='new_cases', kind='line')
plt.title('paraguais')
df_PER.plot(x='days', y='new_cases', kind='line')
plt.title('peru')
df_SUR.plot(x='days', y='new_cases', kind='line')
plt.title('suriname')
df_URU.plot(x='days', y='new_cases', kind='line')
plt.title('uruguais')
df_VEN.plot(x='days', y='new_cases', kind='line')
plt.title('venezuela')
# Out:
# Text(0.5,1,'venezuela')
